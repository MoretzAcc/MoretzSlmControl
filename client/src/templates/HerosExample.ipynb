# %%
from moretzslmclient import importNpyHologram
from heros import HEROObserver

from moretzslmclient import plotHologram

# %%
"""
Check for available Heros
"""
ob = (HEROObserver())
keys = list(ob.known_objects.keys())
print(keys)


heroName = 'slmHero_67fc5727'

# %%
"""
Import hologram
"""
path = "example_hologram_1920x1080.npy"

#hologram = importBmpHologram(path)
hologram = importNpyHologram(path)

plotHologram(hologram)

# %%
"""
Apply hologram
"""
from moretzslmclient import SlmHeroApi

with SlmHeroApi(heroName) as slm:
    slm.setHologramPattern(hologram)
