# %%
from moretzslmclient import importNpyHologram, importBmpHologram, discover_slm_heros, plotHologram, SlmHeroApi

# %%
"""
Check for available Heros
"""
discover_slm_heros()
# Out:
# []

# %%
"""
Set hero name from above output
"""

heroName = 'slm_12345678__example_name' # Put the name of your slm here

# %%
"""
Import hologram
"""
path = "example_hologram_1920x1080.npy"

#hologram = importBmpHologram(path)
hologram = importNpyHologram(path)

plotHologram(hologram)

# %%
"""
Apply hologram
"""
with SlmHeroApi(heroName) as slm:
    slm.setHologramPattern(hologram)
